# %% [markdown]
# # Loading texts into a Database

# %% [markdown]
# Firstly, initialise the Snorkel Session

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os

# TO USE A DATABASE OTHER THAN SQLITE, USE THIS LINE
# Note that this is necessary for parallel execution amongst other things...
# os.environ['SNORKELDB'] = 'postgres:///snorkel-intro'

import numpy as np
from snorkel import SnorkelSession
session = SnorkelSession()

# %% [markdown]
# Then, define the candidate subclass. The ['adjective'] means that the candidate consists of one span named adjective. As snorkel can be used for relation extraction, the examples in snorkel make a list of 2 elements (e.g. ['person1', 'person2']).
# NOTE: Making it just one element meant that  a change in LSTM training needed to be introduced
# TODO: link to the change

# %%
from snorkel.models import candidate_subclass

Sentiment = candidate_subclass('Sentiment', ['adjective'])

# %% [markdown]
# Read the reviews file by file from given directory. All files are at this parsed by spacy, so any previous pre-processing is not neccessary.

# %%
from snorkel.parser import TextDocPreprocessor

from snorkel.parser.spacy_parser import Spacy
from snorkel.parser import CorpusParser

from snorkel.models import Document, Sentence

n_docs = 500
doc_preprocessor = TextDocPreprocessor('./data/reviews')



corpus_parser = CorpusParser(parser=Spacy())
# %time corpus_parser.apply(doc_preprocessor, count=n_docs)

print("Documents:", session.query(Document).count())
print("Sentences:", session.query(Sentence).count())
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# CPU times: user 12.9 s, sys: 175 ms, total: 13.1 s
# Wall time: 13.1 s
# ('Documents:', 500)
# ('Sentences:', 5497)

# %% [markdown]
# ### Candidate matcher
#
# In this task we want to match all adjectives in the text as candidates. In order to achieve that I needed to add a small class to snorkel called AdjectiveMatcher. It takes adavantage of the spacy pre-processsing performed on the inputs and matcches adjectives as candidates.

# %%
from snorkel.candidates import Ngrams, CandidateExtractor
from snorkel.matchers import DictionaryMatch, RegexMatchEach, AdjectiveMatcher

#Read the list of adjectives from a file - no longer used with AdjectiveMatcher
candlist = []
with open('./data/alllisttag.txt', 'r') as alist:
    for line in alist:
        word = line.strip()
        candlist.append(word)

ngrams         = Ngrams(n_max=1)
#word_matcher = DictionaryMatch(d=candlist)
#word_matcher = RegexMatchEach(rgx=r'([A-Za-z]+)/JJ')
word_matcher = AdjectiveMatcher(longest_match_only=True)
cand_extractor = CandidateExtractor(Sentiment, [ngrams], [word_matcher])

# %% [markdown]
# ### Split the data into training, development and test

# %%
from snorkel.models import Document

docs = session.query(Document).order_by(Document.name).all()

train_sents = set()
dev_sents   = set()
test_sents  = set()

for i, doc in enumerate(docs):
    for s in doc.sentences:
        if i % 9 == 7:
            dev_sents.add(s)
        elif i % 9 == 8:
            test_sents.add(s)
        else:
            train_sents.add(s)

# %%
# %%time
for i, sents in enumerate([train_sents, dev_sents, test_sents]):
    cand_extractor.apply(sents, split=i)
    print("Number of candidates:", session.query(Sentiment).filter(Sentiment.split == i).count())
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# ('Number of candidates:', 7542)
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# ('Number of candidates:', 1154)
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# ('Number of candidates:', 899)
# CPU times: user 12.1 s, sys: 214 ms, total: 12.3 s
# Wall time: 12.3 s

# %% [markdown]
# ### Preview the candidates in snorkel viewer
#
# This is just not neccassary for the working of the classification, but helpful when developing to see if things work correctly.

# %%
import snorkel.viewer as sv
sv.SentenceNgramViewer(session.query(Sentiment).filter(Sentiment.split == 1)
                       , session)
# Out:
# U2VudGVuY2VOZ3JhbVZpZXdlcihjaWRzPVtbWzMxNCwgNzA3LCA3NTBdLCBbODcsIDMxNV0sIFsyMjddXSwgW1s5MiwgMjc2XSwgWzM3MV0sIFs3MTRdXSwgW1sxOTVdLCBbODE5XSwgWzgxLCDigKY=

# %% [markdown]
# ## Defining the labelling functions (LFs)

# %%
import re
from snorkel.lf_helpers import (
    get_left_tokens, get_right_tokens, get_between_tokens,
    get_text_between, get_tagged_text,
)
from nltk.corpus import wordnet as wn
import gensim

# Load Google's pre-trained Word2Vec model.
trained_model = gensim.models.KeyedVectors.load_word2vec_format('~/models/GoogleNews-vectors-negative300.bin', binary=True)

# %%
sample_word = "the"


def LF_antonyms(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        synset = wn.synset(word + '.a.01')
        for l in synset.lemmas():
            if l.antonyms():
                return 1
            else:
                return 0
    except:
        return 0
    
def LF_pos_neg_sim(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        pos = trained_model.similarity(word, 'positive')
        neg = trained_model.similarity(word, 'negative')
    except:
        return 0
    if pos > neg:
        return 1
    else:
        return 0

def LF_neg_pos_sim(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        pos = trained_model.similarity(word, 'positive')
        neg = trained_model.similarity(word, 'negative')
    except:
        return 0
    if pos > neg:
        return 0
    else:
        return -1

def LF_good_bad_sim(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        good = trained_model.similarity(word, 'good')
        bad = trained_model.similarity(word, 'bad')
    except:
        return 0
    if good > bad:
        return 1
    else:
        return 0
    '''
    if 'happy' in c.get_parent().words:
        print("Yasss")
    w_len = get_left_tokens(c[0], window=7)
    word = None
    try:
        word = next(w_len)
    except:
        pass
    if word == sample_word:
        return 1
    else:
        return 0
        
    '''

# %% [markdown]
# #### Checking if an LF works
# Test the working of a labelling function - for instance, LF_pos_neg_sim is tested here. This step is here as halper for developing LFs, can be skipped when we just want to run the full classification.

# %%
labeled = []
for c in session.query(Sentiment).all():
    if LF_pos_neg_sim(c) != 0:
        labeled.append(c)
print("Number labeled:", len(labeled))
# Out:
# ('Number labeled:', 5489)

# %%
import snorkel.viewer as sv
sv.SentenceNgramViewer(labeled, session)
# Out:
# U2VudGVuY2VOZ3JhbVZpZXdlcihjaWRzPVtbWzEyOCwgNDI5MCwgNDM2Ml0sIFsyNTQ2XSwgWzIyMzZdXSwgW1sxMjY5XSwgWzM1OTJdLCBbMzcwNV1dLCBbWzM1OF0sIFsyMTUxXSwgWzU2N13igKY=

# %% [markdown]
# Insert the labelling functions that you want to use into a list.

# %%
LFs = [
    LF_pos_neg_sim,  LF_good_bad_sim, LF_antonyms, 
]

# %% [markdown]
# ### Load the gold labels from external file
#
# Uses util.py file located in the same directory. Within the util.py file the path to the file with gold annotations is provided.
# NOTE: Label loading code in snorkel is nondestructive, so re-running this cell within the same session won't replace existing labels in the database.

# %%
from util import load_external_labels

# %time missed = load_external_labels(session, Sentiment, annotator_name='gold')
# Out:
# AnnotatorLabels created: 681
# AnnotatorLabels created: 573
# CPU times: user 1min 46s, sys: 520 ms, total: 1min 47s
# Wall time: 1min 47s

# %%
from snorkel.annotations import load_gold_labels


L_gold_dev = load_gold_labels(session, annotator_name='gold', split=1)

# %%
from snorkel.annotations import LabelAnnotator
labeler = LabelAnnotator(lfs=LFs)

# %%
np.random.seed(1701)
# %time L_train = labeler.apply(split=0)
L_train
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# CPU times: user 27.9 s, sys: 124 ms, total: 28.1 s
# Wall time: 28.2 s
# <7542x3 sparse matrix of type '<type 'numpy.int64'>'
# 	with 12495 stored elements in Compressed Sparse Row format>

# %%
# %time L_train = labeler.load_matrix(session, split=0)
L_train
# Out:
# CPU times: user 104 ms, sys: 0 ns, total: 104 ms
# Wall time: 103 ms
# <7542x3 sparse matrix of type '<type 'numpy.int64'>'
# 	with 12495 stored elements in Compressed Sparse Row format>

# %%
L_train.get_candidate(session, 0)
# Out:
# Sentiment(Span("hot", sentence=3082, chars=[45,47], words=[8,8]))

# %%
L_train.get_key(session, 0)
# Out:
# LabelKey (LF_pos_neg_sim)

# %% [markdown]
# * **Coverage** is the fraction of candidates that the labeling function emits a non-zero label for.
# * **Overlap** is the fraction candidates that the labeling function emits a non-zero label for and that another labeling function emits a non-zero label for.
# * **Conflict** is the fraction candidates that the labeling function emits a non-zero label for and that another labeling function emits a *conflicting* non-zero label for.

# %%
L_train.lf_stats(session)
# Out:
#                  j  Coverage  Overlaps  Conflicts
# LF_pos_neg_sim   0  0.569212  0.525855        0.0
# LF_good_bad_sim  1  0.578494  0.512729        0.0
# LF_antonyms      2  0.509016  0.371122        0.0

# %% [markdown]
# ## Fitting the Generative Model

# %%
from snorkel.learning import GenerativeModel

gen_model = GenerativeModel()
gen_model.train(L_train, epochs=100, decay=0.95, step_size=0.1 / L_train.shape[0], reg_param=1e-6)
# Out:
# Inferred cardinality: 2

# %% [markdown]
# #### Insight into the model
# Can be skipped if just looking for the final results.

# %%
gen_model.weights.lf_accuracy
# Out:
# array([ 0.94323123,  0.95223951,  0.78428614])

# %%
train_marginals = gen_model.marginals(L_train)

# %%
import matplotlib.pyplot as plt
plt.hist(train_marginals, bins=20)
plt.show()

# %%
gen_model.learned_lf_stats()
# Out:
#    Accuracy  Coverage  Precision    Recall
# 0  0.871764    0.7455   0.867477  0.643457
# 1  0.868888    0.7444   0.859239  0.647553
# 2  0.827227    0.7287   0.819645  0.604956

# %% [markdown]
# ## Debugging Labelling Functions

# %% [markdown]
# Load L_gold_dev for the dev set.

# %%
L_dev = labeler.apply_existing(split=1)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%

# %% [markdown]
# Scores for the dev set.

# %%
tp, fp, tn, fn = gen_model.error_analysis(session, L_dev, L_gold_dev)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.931
# Neg. class accuracy: 0.255
# Precision            0.336
# Recall               0.931
# F1                   0.493
# ----------------------------------------
# TP: 309 | FP: 612 | TN: 210 | FN: 23
# ========================================

# %%
from snorkel.viewer import SentenceNgramViewer

# NOTE: This if-then statement is only to avoid opening the viewer during automated testing of this notebook
# You should ignore this!
import os
if 'CI' not in os.environ:
    sv = SentenceNgramViewer(fp, session)
else:
    sv = None

# %%
sv
# Out:
# U2VudGVuY2VOZ3JhbVZpZXdlcihjaWRzPVtbWzM4OF0sIFsxNjldLCBbMjA5XV0sIFtbMzk3XSwgWzExMV0sIFs0NDRdXSwgW1s0NiwgNDY3XSwgWzUyNV0sIFsyMzddXSwgW1s1NTksIDU5OCzigKY=

# %%
L_dev.lf_stats(session, L_gold_dev, gen_model.learned_lf_stats()['Accuracy'])
# Out:
#                  j  Coverage  Overlaps  Conflicts   TP   FP  FN  TN  \
# LF_pos_neg_sim   0  0.544194  0.506932        0.0  259  164   0   0
# LF_good_bad_sim  1  0.577990  0.503466        0.0  259  180   0   0
# LF_antonyms      2  0.491334  0.347487        0.0  210  182   0   0
#
#                  Empirical Acc.  Learned Acc.
# LF_pos_neg_sim         0.612293      0.867097
# LF_good_bad_sim        0.589977      0.866569
# LF_antonyms            0.535714      0.834747

# %%
from snorkel.annotations import save_marginals
# %time save_marginals(session, L_train, train_marginals)
# Out:
# Saved 7542 marginals
# CPU times: user 4.43 s, sys: 24.1 ms, total: 4.45 s
# Wall time: 4.45 s

# %%
from snorkel.annotations import load_marginals

train_marginals = load_marginals(session, split=0)

# %%
train_cands = session.query(Sentiment).filter(Sentiment.split == 0).order_by(Sentiment.id).all()
dev_cands   = session.query(Sentiment).filter(Sentiment.split == 1).order_by(Sentiment.id).all()
test_cands  = session.query(Sentiment).filter(Sentiment.split == 2).order_by(Sentiment.id).all()

# %%
from snorkel.annotations import load_gold_labels

L_gold_dev  = load_gold_labels(session, annotator_name='gold', split=1)
L_gold_test = load_gold_labels(session, annotator_name='gold', split=2)

# %%
from snorkel.learning.pytorch.rnn import LSTM

train_kwargs = {
    'lr':         0.001,
    'dim':        100,
    'n_epochs':   50,
    'dropout':    0.25,
    'print_freq': 1,
    'batch_size': 128,
    'max_sentence_length': 100
}

lstm = LSTM(n_threads=1)
lstm.train(train_cands, train_marginals, X_dev=dev_cands, Y_dev=L_gold_dev, **train_kwargs)
# Out:
# [LSTM] Training model
# [LSTM] n_train=6086  #epochs=50  batch size=128
# [LSTM] Epoch 1 (7.85s)	Average loss=0.473463	Dev F1=44.68
# [LSTM] Epoch 2 (16.69s)	Average loss=0.410355	Dev F1=44.68
# [LSTM] Epoch 3 (25.55s)	Average loss=0.405325	Dev F1=44.68
# [LSTM] Epoch 4 (34.27s)	Average loss=0.401988	Dev F1=44.68
# [LSTM] Epoch 5 (44.06s)	Average loss=0.398766	Dev F1=44.68
# [LSTM] Epoch 6 (52.92s)	Average loss=0.392839	Dev F1=44.68
# [LSTM] Epoch 7 (62.12s)	Average loss=0.384664	Dev F1=44.68
# [LSTM] Epoch 8 (73.21s)	Average loss=0.375877	Dev F1=44.77
# [LSTM] Epoch 9 (85.47s)	Average loss=0.367878	Dev F1=44.77
# [LSTM] Epoch 10 (95.16s)	Average loss=0.353708	Dev F1=44.77
# [LSTM] Epoch 11 (104.10s)	Average loss=0.345566	Dev F1=44.71
# [LSTM] Epoch 12 (112.97s)	Average loss=0.333418	Dev F1=44.71
# [LSTM] Epoch 13 (126.05s)	Average loss=0.326364	Dev F1=44.77
# [LSTM] Epoch 14 (139.04s)	Average loss=0.318544	Dev F1=44.77
# [LSTM] Epoch 15 (150.25s)	Average loss=0.313469	Dev F1=44.83
# [LSTM] Epoch 16 (158.96s)	Average loss=0.312127	Dev F1=44.93
# [LSTM] Epoch 17 (167.60s)	Average loss=0.306047	Dev F1=44.96
# [LSTM] Epoch 18 (176.35s)	Average loss=0.302594	Dev F1=44.99
# [LSTM] Epoch 19 (185.11s)	Average loss=0.298797	Dev F1=44.99
# [LSTM] Epoch 20 (193.73s)	Average loss=0.296941	Dev F1=44.90
# [LSTM] Epoch 21 (202.47s)	Average loss=0.295052	Dev F1=45.05
# [LSTM] Epoch 22 (211.16s)	Average loss=0.293926	Dev F1=45.06
# [LSTM] Epoch 23 (219.98s)	Average loss=0.292132	Dev F1=44.93
# [LSTM] Epoch 24 (228.66s)	Average loss=0.290163	Dev F1=45.00
# [LSTM] Epoch 25 (237.42s)	Average loss=0.290396	Dev F1=45.13
# [LSTM] Epoch 26 (246.16s)	Average loss=0.289223	Dev F1=45.16
# [LSTM] Epoch 27 (254.84s)	Average loss=0.287529	Dev F1=45.19
# [LSTM] Epoch 28 (263.54s)	Average loss=0.286989	Dev F1=45.19
# [LSTM] Epoch 29 (272.21s)	Average loss=0.286548	Dev F1=45.31
# [LSTM] Epoch 30 (280.95s)	Average loss=0.285665	Dev F1=45.28
# [LSTM] Epoch 31 (289.78s)	Average loss=0.285142	Dev F1=45.31
# [LSTM] Epoch 32 (298.53s)	Average loss=0.284578	Dev F1=45.31
# [LSTM] Epoch 33 (307.26s)	Average loss=0.293233	Dev F1=44.70
# [LSTM] Epoch 34 (315.98s)	Average loss=0.287032	Dev F1=45.47
# [LSTM] Epoch 35 (324.73s)	Average loss=0.284469	Dev F1=45.37
# [LSTM] Epoch 36 (333.40s)	Average loss=0.284491	Dev F1=45.02
# [LSTM] Epoch 37 (342.04s)	Average loss=0.283196	Dev F1=45.33
# [LSTM] Epoch 38 (350.71s)	Average loss=0.282852	Dev F1=45.45
# [LSTM] Epoch 39 (359.37s)	Average loss=0.283235	Dev F1=45.55
# [LSTM] Model saved as <LSTM>
# [LSTM] Epoch 40 (368.56s)	Average loss=0.283021	Dev F1=45.36
# [LSTM] Epoch 41 (379.89s)	Average loss=0.284560	Dev F1=45.51
# [LSTM] Epoch 42 (390.12s)	Average loss=0.283408	Dev F1=45.09
# [LSTM] Epoch 43 (399.05s)	Average loss=0.282605	Dev F1=45.27
# [LSTM] Epoch 44 (410.52s)	Average loss=0.282228	Dev F1=45.26
# [LSTM] Epoch 45 (422.31s)	Average loss=0.283076	Dev F1=45.25
# [LSTM] Epoch 46 (431.40s)	Average loss=0.281770	Dev F1=45.42
# [LSTM] Epoch 47 (440.15s)	Average loss=0.281302	Dev F1=45.36
# [LSTM] Epoch 48 (448.89s)	Average loss=0.281005	Dev F1=45.39
# [LSTM] Epoch 49 (457.66s)	Average loss=0.280858	Dev F1=45.40
# [LSTM] Epoch 50 (466.85s)	Average loss=0.281134	Dev F1=45.47
# [LSTM] Training done (467.69s)
# [LSTM] Loaded model <LSTM>

# %%
p, r, f1 = lstm.score(test_cands, L_gold_test)
print("Prec: {0:.3f}, Recall: {1:.3f}, F1 Score: {2:.3f}".format(p, r, f1))
# Out:
# Prec: 0.336, Recall: 0.973, F1 Score: 0.499

# %%
tp, fp, tn, fn = lstm.error_analysis(session, test_cands, L_gold_test)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.973
# Neg. class accuracy: 0.0449
# Precision            0.336
# Recall               0.973
# F1                   0.499
# ----------------------------------------
# TP: 290 | FP: 574 | TN: 27 | FN: 8
# ========================================

# %%
lstm.save_marginals(session, test_cands)
# Out:
# Saved 899 marginals

# %% [markdown]
# # Negative vs Non-negative classification

# %%
from util import load_external_labels

# %time missed = load_external_labels(session, Sentiment, annotator_name='gold', setup = 'neg')
# Out:
# haha
# AnnotatorLabels created: 678
# AnnotatorLabels created: 572
# CPU times: user 44.3 s, sys: 29.9 ms, total: 44.3 s
# Wall time: 44.4 s

# %%
import re
from snorkel.lf_helpers import (
    get_left_tokens, get_right_tokens, get_between_tokens,
    get_text_between, get_tagged_text,
)
from nltk.corpus import wordnet as wn
import gensim

# Load Google's pre-trained Word2Vec model.
trained_model = gensim.models.KeyedVectors.load_word2vec_format('~/models/GoogleNews-vectors-negative300.bin', binary=True)

# %%
sample_word = "the"


def LF_antonyms(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        synset = wn.synset(word + '.a.01')
        for l in synset.lemmas():
            if l.antonyms():
                return 1
            else:
                return -1
    except:
        return 0
    
def LF_pos_neg_sim(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        pos = trained_model.similarity(word, 'positive')
        neg = trained_model.similarity(word, 'negative')
    except:
        return 0
    if pos > neg:
        return -1
    else:
        return 1

def LF_neg_pos_sim(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        pos = trained_model.similarity(word, 'positive')
        neg = trained_model.similarity(word, 'negative')
    except:
        return 0
    if pos > neg:
        return 0
    else:
        return 1

def LF_good_bad_sim(c):
    word = (c.adjective.get_span().encode('utf-8'))
    try:
        good = trained_model.similarity(word, 'good')
        bad = trained_model.similarity(word, 'bad')
    except:
        return 0
    if good > bad:
        return -1
    else:
        return 1

# %%
LFs = [
    LF_pos_neg_sim,  LF_good_bad_sim #, LF_antonyms, 
]

# %%
labeled = []
for c in session.query(Sentiment).all():
    if LF_pos_neg_sim(c) != 0:
        labeled.append(c)
print("Number labeled:", len(labeled))
# Out:
# ('Number labeled:', 9310)

# %%
from snorkel.annotations import load_gold_labels
from snorkel.annotations import LabelAnnotator

L_gold_dev = load_gold_labels(session, annotator_name='gold', split=1)

from snorkel.annotations import LabelAnnotator
labeler = LabelAnnotator(lfs=LFs)
np.random.seed(1701)
# %time L_train = labeler.apply(split=0)
L_train
# %time L_train = labeler.load_matrix(session, split=0)
L_train.lf_stats(session)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# CPU times: user 26.2 s, sys: 44.3 ms, total: 26.3 s
# Wall time: 26.3 s
# CPU times: user 115 ms, sys: 0 ns, total: 115 ms
# Wall time: 115 ms
#                  j  Coverage  Overlaps  Conflicts
# LF_pos_neg_sim   0  0.968443  0.968443     0.1904
# LF_good_bad_sim  1  0.968443  0.968443     0.1904

# %%
from snorkel.learning import GenerativeModel

gen_model = GenerativeModel()
gen_model.train(L_train, epochs=100, decay=0.95, step_size=0.1 / L_train.shape[0], reg_param=1e-6)

train_marginals = gen_model.marginals(L_train)
# Out:
# Inferred cardinality: 2

# %%
gen_model.learned_lf_stats()
# Out:
#    Accuracy  Coverage  Precision    Recall
# 0  0.944245    0.8089   0.943190  0.761771
# 1  0.945568    0.8157   0.946144  0.774394

# %%
L_dev = labeler.apply_existing(split=1)

tp, fp, tn, fn = gen_model.error_analysis(session, L_dev, L_gold_dev)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%
#
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.53
# Neg. class accuracy: 0.644
# Precision            0.357
# Recall               0.53
# F1                   0.427
# ----------------------------------------
# TP: 166 | FP: 299 | TN: 542 | FN: 147
# ========================================

# %%
from snorkel.viewer import SentenceNgramViewer

# NOTE: This if-then statement is only to avoid opening the viewer during automated testing of this notebook
# You should ignore this!
import os
if 'CI' not in os.environ:
    sv = SentenceNgramViewer(fp, session)
else:
    sv = None
    
sv
# Out:
# U2VudGVuY2VOZ3JhbVZpZXdlcihjaWRzPVtbWzE2OSwgMTgxXSwgWzIxLCA2OV0sIFs1MV1dLCBbWzYyXSwgWzE0NV0sIFs5NF1dLCBbWzIzMV0sIFsxNl0sIFswLCAyNDRdXSwgW1sxNjUsIDLigKY=

# %%
L_dev.lf_stats(session, L_gold_dev, gen_model.learned_lf_stats()['Accuracy'])
# Out:
#                  j  Coverage  Overlaps  Conflicts   TP  FP   FN   TN  \
# LF_pos_neg_sim   0  0.980936  0.980936   0.186308  165  92  148  273
# LF_good_bad_sim  1  0.980936  0.980936   0.186308  166  76  147  289
#
#                  Empirical Acc.  Learned Acc.
# LF_pos_neg_sim         0.646018      0.940561
# LF_good_bad_sim        0.671091      0.944540

# %%
from snorkel.annotations import save_marginals
# %time save_marginals(session, L_train, train_marginals)
# Out:
# Saved 7542 marginals
# CPU times: user 4.41 s, sys: 16 ms, total: 4.42 s
# Wall time: 4.42 s

# %%
from snorkel.annotations import load_marginals

train_marginals = load_marginals(session, split=0)

train_cands = session.query(Sentiment).filter(Sentiment.split == 0).order_by(Sentiment.id).all()
dev_cands   = session.query(Sentiment).filter(Sentiment.split == 1).order_by(Sentiment.id).all()
test_cands  = session.query(Sentiment).filter(Sentiment.split == 2).order_by(Sentiment.id).all()

# %%
from snorkel.annotations import load_gold_labels

L_gold_dev  = load_gold_labels(session, annotator_name='gold', split=1)
L_gold_test = load_gold_labels(session, annotator_name='gold', split=2)

# %%
from snorkel.learning.pytorch.rnn import LSTM

train_kwargs = {
    'lr':         0.001,
    'dim':        100,
    'n_epochs':   20,
    'dropout':    0.25,
    'print_freq': 1,
    'batch_size': 128,
    'max_sentence_length': 100
}

lstm = LSTM(n_threads=1)
lstm.train(train_cands, train_marginals, X_dev=dev_cands, Y_dev=L_gold_dev, **train_kwargs)
# Out:
# [LSTM] Training model
# [LSTM] n_train=7304  #epochs=20  batch size=128
# [LSTM] Epoch 1 (9.39s)	Average loss=0.680582	Dev F1=0.62
# [LSTM] Epoch 2 (19.64s)	Average loss=0.678457	Dev F1=0.63
# [LSTM] Epoch 3 (30.02s)	Average loss=0.670262	Dev F1=13.33
# [LSTM] Epoch 4 (40.19s)	Average loss=0.649473	Dev F1=27.99
# [LSTM] Epoch 5 (50.21s)	Average loss=0.604170	Dev F1=40.10
# [LSTM] Epoch 6 (60.23s)	Average loss=0.522393	Dev F1=41.77
# [LSTM] Epoch 7 (70.38s)	Average loss=0.490552	Dev F1=41.63
# [LSTM] Epoch 8 (80.54s)	Average loss=0.452133	Dev F1=40.36
# [LSTM] Epoch 9 (90.56s)	Average loss=0.411493	Dev F1=42.35
# [LSTM] Epoch 10 (100.74s)	Average loss=0.375031	Dev F1=41.95
# [LSTM] Epoch 11 (110.86s)	Average loss=0.347801	Dev F1=40.21
# [LSTM] Epoch 12 (121.00s)	Average loss=0.346493	Dev F1=42.52
# [LSTM] Epoch 13 (131.84s)	Average loss=0.313868	Dev F1=41.71
# [LSTM] Epoch 14 (143.03s)	Average loss=0.326292	Dev F1=41.34
# [LSTM] Epoch 15 (154.29s)	Average loss=0.371398	Dev F1=42.35
# [LSTM] Epoch 16 (166.58s)	Average loss=0.328673	Dev F1=43.05
# [LSTM] Epoch 17 (177.02s)	Average loss=0.379258	Dev F1=41.18
# [LSTM] Model saved as <LSTM>
# [LSTM] Epoch 18 (187.20s)	Average loss=0.334966	Dev F1=37.61
# [LSTM] Epoch 19 (198.67s)	Average loss=0.311344	Dev F1=41.14
# [LSTM] Epoch 20 (210.08s)	Average loss=0.283021	Dev F1=40.33
# [LSTM] Training done (210.94s)
# [LSTM] Loaded model <LSTM>

# %%
tp, fp, tn, fn = lstm.error_analysis(session, test_cands, L_gold_test)
